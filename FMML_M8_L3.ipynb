# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanmukha2775/Fmml-lab-2024/blob/main/FMML_M8_L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 04:15:55--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   196MB/s    in 0.4s
#
# 2025-03-16 04:15:57 (196 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2061 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 1666 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 426  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 15  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26848  1701.00295v4  We propose a unified formulation for the probl...    cs
# 37881   1011.4832v3  Modern statistical applications involving larg...  stat
# 20908  1705.02477v1  As manufacturing processes become increasingly...    cs
# 11988  1705.10498v2  Determinantal point processes (DPPs) are distr...  stat
# 22840  1708.05257v1  Bayesian models that mix multiple Dirichlet pr...  stat
# ...             ...                                                ...   ...
# 22602  1702.06209v1  Hypothesis tests in models whose dimension far...  stat
# 6282   1610.08861v1  Positive-definite kernel functions are fundame...  stat
# 31352  1803.01071v1  Sky/cloud images obtained from ground-based sk...    cs
# 21761   1207.3649v1  We consider probabilistic multinomial probit c...  stat
# 22427  1606.07840v1  We propose a probabilistic modeling framework ...  stat
#
#                                                    title  year  \
# 26848  Lifting from the Deep: Convolutional 3D Pose E...  2017
# 37881  Variational approximation for heteroscedastic ...  2010
# 20908  Metacognitive Learning Approach for Online Too...  2017
# 11988  Zonotope hit-and-run for efficient sampling fr...  2017
# 22840     Auxiliary Variables for Multi-Dirichlet Priors  2017
# ...                                                  ...   ...
# 22602  Uniform Inference for High-dimensional Quantil...  2017
# 6282   On Bochner's and Polya's Characterizations of ...  2016
# 31352  High-Dynamic-Range Imaging for Cloud Segmentation  2018
# 21761  Nested Expectation Propagation for Gaussian Pr...  2012
# 22427  Modeling Group Dynamics Using Probabilistic Te...  2016
#
#                                                 keywords
# 26848  [formulation, estimation, estimation, reconstr...
# 37881  [statistical, applications, involving, attenti...
# 20908  [manufacturing, processes, increasingly, autom...
# 11988  [determinantal, processes, distributions, dive...
# 22840  [dirichlet, parameters, dirichlet, popularity,...
# ...                                                  ...
# 22602  [hypothesis, dimension, formulated, classical,...
# 6282   [functions, fundamental, processes, constructi...
# 31352  [luminance, conventional, difficult, circumsol...
# 21761  [probabilistic, multinomial, classification, c...
# 22427  [probabilistic, framework, collective, behavio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26848    [formulation, estimation, estimation, reconstr...
# 37881    [statistical, applications, involving, attenti...
# 20908    [manufacturing, processes, increasingly, autom...
# 11988    [determinantal, processes, distributions, dive...
# 22840    [dirichlet, parameters, dirichlet, popularity,...
#                                ...
# 36431    [reasoning, abilities, coalitions, transferrin...
# 28230    [classification, extending, unsupervised, disc...
# 12463    [exploratory, developing, effective, classific...
# 18188    [hypotheses, observations, experiments, observ...
# 35698    [methodology, automated, detection, classifica...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8775 words.
# Out of those 4603 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a60cc90-3478-4ee0-a4ae-bd0b596f74c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a60cc90-3478-4ee0-a4ae-bd0b596f74c7")) {                    Plotly.newPlot(                        "3a60cc90-3478-4ee0-a4ae-bd0b596f74c7",                        [{"x":["plausible","reconstruction","locations","integrated","architecture","approaches","estimation","extremely","efficient","convolutional","knowledge","outperforming","formulation","probabilistic","heteroscedastic","regression","progression","applications","predictors","variables","dimensional","approximation","algorithm","technology","orthogonal","extending","methodologies","constituents","inference","methodology","framework","candidate","likelihood","selection","involving","different","potentially","variational","computationally","statistical","simulations","functions","described","prediction","algorithms","screening","predictor","optimization","attention","counterparts","mechanisms","traditional","recurrent","condition","increasingly","scaffolding","intelligent","continuously","demonstrated","published","structure","automated","retaining","classifier","conducted","generalized","monitoring","cognitive","determine","complexity","component","experimental","manufacturing","processes","regulating","impractical","therefore","theoretical","combinatorial","projection","determinantal","distributions","distribution","approximate","demonstrate","leverages","targeting","convergence","translates","triggered","programming","experiments","recommendation","prohibitive","empirical","extraction","efficiently","diversity","cardinality","hierarchical","complicate","popularity","parameters","collapsed","inferring","dirichlet","auxiliary","covariance","multivariate","providing","combinations","modelling","relationship","conflicting","frequencies","differences","synthetic","covariances","rationale","understand","interpretation","expressive","constructed","validated","magnitudes","interpret","parametric","independent","principled","densities","introduce","gradients","difficulty","performing","relatively","incorporating","stochastic","estimates","effectively","comparably","parameter","computation","simulation","hamiltonian","introduced","characterize","parallelization","dependent","furthermore","averaging","analyzing","fundamental","establishes","conjunction","significantly","characterizes","techniques","asymptotic","parallelizing","parallelizable","generalizing","generalization","stepsizes","computational","properties","operators","particular","developing","regularized","presented","assumption","estimators","nonparametric","important","statistics","dimensions","additionally","reproducing","generated","semiparametric","depending","favourably","scientific","representation","discusses","considered","reasoning","technological","processing","extensions","development","application","predictions","transparent","information","recognition","translation","interpretability","increasing","performance"],"y":[26,126,35,58,229,421,186,39,412,383,331,24,73,167,0,120,11,393,13,135,181,109,807,60,22,29,16,4,224,68,536,48,58,155,57,756,44,43,106,167,44,207,71,256,610,9,11,313,167,12,54,173,132,58,45,2,64,16,95,37,336,95,10,161,72,69,27,45,71,237,100,375,8,115,1,13,138,158,39,46,0,99,202,94,554,22,9,123,4,4,111,611,36,13,162,123,151,47,11,89,0,20,257,1,26,13,17,18,18,87,39,58,66,5,14,58,135,4,4,64,60,28,61,34,2,21,34,127,31,5,337,39,50,96,62,65,134,84,122,6,114,159,76,4,139,43,10,87,151,23,54,90,11,18,261,12,368,19,2,8,10,118,0,284,213,48,257,67,37,177,68,14,18,375,58,43,64,9,182,0,22,4,39,368,31,103,117,7,270,45,126,267,89,11,712,356,128,15,92,871],"type":"bar"},{"x":["plausible","reconstruction","locations","i ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4603,), (4603, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Popular</span> <span style=''>Ensemble</span> <span style=''>Methods</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Study</span> <br/><br/><span style=''>An</span> <span style=''>ensemble</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individually</span> <span style=''>trained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>(such</span> <span style=''>as</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>or</span> <span style=''>decision</span> <span style=''>trees)</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>are</span> <span style=''>combined</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifying</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instances</span> <span style=''>Previous</span> <span style=''>research</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>is</span> <span style=''>often</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>than</span> <span style=''>any</span> <span style=''>of</span> <span style=''>the</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>in</span> <span style=''>the</span> <span style=''>ensemble</span> <span style=''>Bagging</span> <span style=''>(Breiman</span> <span style=''>1996c)</span> <span style=''>and</span> <span style=''>Boosting</span> <span style=''>(Freund</span> <span style=''>and</span> <span style=''>Shapire</span> <span style=''>1996</span> <span style=''>Shapire</span> <span style=''>1990)</span> <span style=''>are</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>new</span> <span style=''>but</span> <span style=''>popular</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521735);'>producing</span> <span style='background-color:rgba(255, 0, 0, 0.32000000000000006);'>ensembles</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>evaluate</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>on</span> <span style=''>23</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>using</span> <span style=''>both</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>as</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>clearly</span> <span style=''>indicate</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conclusions</span> <span style=''>First</span> <span style=''>while</span> <span style=''>Bagging</span> <span style=''>is</span> <span style=''>almost</span> <span style=''>always</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>than</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sometimes</span> <span style=''>much</span> <span style=''>less</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Location</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(DP)</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>applied</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>modeling</span> <span style=''>However</span> <span style=''>in</span> <span style=''>their</span> <span style=''>basic</span> <span style=''>form</span> <span style=''>they</span> <span style=''>do</span> <span style=''>not</span> <span style=''>directly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>among</span> <span style=''>data</span> <span style=''>arising</span> <span style=''>from</span> <span style=''>space</span> <span style=''>and</span> <span style=''>time</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>location</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(LDDP)</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>DP</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>model</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>the</span> <span style=''>LDDP</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>mixture</span> <span style=''>modeling</span> <span style=''>and</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>mean</span> <span style=''>field</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>this</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>on</span> <span style=''>an</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>task</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.32499999999999996);'>Understanding</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Boltzmann</span> <span style=''>Machine</span> <span style=''>and</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>via</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Confident</span> <span style='background-color:rgba(0, 255, 0, 0.3052245646196151);'>Information</span> <span style=''>First</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principle</span> <br/><br/><span style=''>Typical</span> <span style='background-color:rgba(255, 0, 0, 0.3191489361702128);'>dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>methods</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>directly</span> <span style=''>reducing</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.334975369458128);'>variables</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retaining</span> <span style=''>maximal</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>variations</span> <span style=''>in</span> <span style=''>the</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3191489361702128);'>dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3006134969325154);'>parameter</span> <span style=''>spaces</span> <span style=''>of</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.7024793388429753);'>multivariate</span> <span style='background-color:rgba(255, 0, 0, 0.3926380368098158);'>distributions</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Confident</span> <span style='background-color:rgba(0, 255, 0, 0.3052245646196151);'>Information</span> <span style=''>First</span> <span style=''>(CIF)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style=''>preserve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confident</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>and</span> <span style=''>rule</span> <span style=''>out</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>unreliable</span> <span style=''>or</span> <span style=''>noisy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>Formally</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3006134969325154);'>parameter</span> <span style=''>can</span> <span style=''>be</span> <span style=''>assessed</span> <span style=''>by</span> <span style=''>its</span> <span style=''>Fisher</span> <span style='background-color:rgba(0, 255, 0, 0.3052245646196151);'>information</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establishes</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>with</span> <span style=''>the</span> <span style=''>inverse</span> <span style=''>variance</span> <span style=''>of</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Task</span> <span style=''>Policy</span> <span style=''>Search</span> <br/><br/><span style=''>Learning</span> <span style=''>policies</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>tasks</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>research</span> <span style=''>topic</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>robotics</span> <span style=''>Training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>policies</span> <span style=''>for</span> <span style=''>every</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>task</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impractical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requiring</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>share</span> <span style=''>and</span> <span style=''>transfer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>among</span> <span style=''>similar</span> <span style=''>tasks</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>feedback</span> <span style=''>policy</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>define</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrized</span> <span style=''>policy</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>both</span> <span style=''>the</span> <span style=''>state</span> <span style=''>and</span> <span style=''>the</span> <span style=''>task</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>single</span> <span style=''>policy</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>known</span> <span style=''>and</span> <span style=''>unknown</span> <span style=''>tasks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Applications</span> <span style=''>of</span> <span style=''>our</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imitation</span> <span style=''>learning</span> <span style=''>in</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08228530362917715)
# 	automatic (0.06970894717930291)
# 	segmentation (0.06647502694933526)
# 	experimental (0.13474667624865252)
# 	representation (0.1322314049586777)
# 	detection (0.11390585698886094)
# 	information (0.2558390226374416)
# 	different (0.2716492993172835)
# 	recognition (0.1279195113187208)
# 	convolutional (0.13762127200862379)
#
# Some Statistics words are:
# 	statistical (0.14476945959345563)
# 	variational (0.10064452156668319)
# 	variables (0.13435795736241943)
# 	algorithm (0.37927615270203274)
# 	estimation (0.16162617749132374)
# 	theoretical (0.15666831928606842)
# 	distribution (0.18889439762022806)
# 	dimensional (0.18294496777392166)
# 	inference (0.20426375805651958)
# 	regression (0.17253346554288548)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ad8e1b46-489d-4042-912f-68b5545a6c33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad8e1b46-489d-4042-912f-68b5545a6c33")) {                    Plotly.newPlot(                        "ad8e1b46-489d-4042-912f-68b5545a6c33",                        [{"x":["plausible","reconstruction","locations","integrated","architecture","approaches","estimation","extremely","efficient","convolutional","knowledge","outperforming","formulation","probabilistic","heteroscedastic","regression","progression","applications","predictors","variables","dimensional","approximation","algorithm","technology","orthogonal","extending","methodologies","constituents","inference","methodology","framework","candidate","likelihood","selection","involving","different","potentially","variational","computationally","statistical","simulations","functions","described","prediction","algorithms","screening","predictor","optimization","attention","counterparts","mechanisms","traditional","recurrent","condition","increasingly","scaffolding","intelligent","continuously","demonstrated","published","structure","automated","retaining","classifier","conducted","generalized","monitoring","cognitive","determine","complexity","component","experimental","manufacturing","processes","regulating","impractical","therefore","theoretical","combinatorial","projection","determinantal","distributions","distribution","approximate","demonstrate","leverages","targeting","convergence","translates","triggered","programming","experiments","recommendation","prohibitive","empirical","extraction","efficiently","diversity","cardinality","hierarchical","complicate","popularity","parameters","collapsed","inferring","dirichlet","auxiliary","covariance","multivariate","providing","combinations","modelling","relationship","conflicting","frequencies","differences","synthetic","covariances","rationale","understand","interpretation","expressive","constructed","validated","magnitudes","interpret","parametric","independent","principled","densities","introduce","gradients","difficulty","performing","relatively","incorporating","stochastic","estimates","effectively","comparably","parameter","computation","simulation","hamiltonian","introduced","characterize","parallelization","dependent","furthermore","averaging","analyzing","fundamental","establishes","conjunction","significantly","characterizes","techniques","asymptotic","parallelizing","parallelizable","generalizing","generalization","stepsizes","computational","properties","operators","particular","developing","regularized","presented","assumption","estimators","nonparametric","important","statistics","dimensions","additionally","reproducing","generated","semiparametric","depending","favourably","scientific","representation","discusses","considered","reasoning","technological","processing","extensions","development","application","predictions","transparent","information","recognition","translation","interpretability","increasing","performance","narrowing","revolutionize","combining","complementary","understandable","interpretable","improvement","consistency","regularizing","criterion","effectiveness","witnessed","posterior","employing","guarantee","sufficient","probability","effective","uncertainties","assumptions","interactively","scenarios","dimension","influence","clustering","existence","supervised","logarithmic","dependency","abstraction","realistic","overcoming","conditions","minimizes","hypothesis","treatment","accordingly","currently","classification","viewpoint","necessary","activities","discrimination","identifying","neutrality","classifiers","specifically","individual","simultaneously","realization","sacrificing","guaranteed","minimiza ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	heteroscedastic
# 	determinantal
# 	complicate
# 	stepsizes
# 	semiparametric
# 	physiologic
# 	phenotype
# 	quadrature
# 	prognostic
# 	gaussianity
# 	recoverability
# 	exemplify
# 	submatrix
# 	planetary
# 	timelines
# 	repulsion
# 	practiced
# 	replicable
# 	sparsistent
# 	certifiable
# Some words which never appear in Statistics papers:
# 	scaffolding
# 	observability
# 	constituting
# 	envisioned
# 	personality
# 	pragmatic
# 	thickness
# 	annotator
# 	sensorimotor
# 	connectionist
# 	eligibility
# 	truncating
# 	controversy
# 	misconceptions
# 	fallacies
# 	assistive
# 	communicative
# 	deficiencies
# 	concluded
# 	susceptibility

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0832793759442546e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
